# %% [markdown]
# # Used Car Prices
# In this project we will explore how to use CatBoost, an algorithm for gradient boosting on decision trees. The dataset contains historical car auction sales prices and was scraped from outside internet sources. The dataset has been collected in 2015. The dataset can be found in following link: https://www.kaggle.com/tunguz/used-car-auction-prices

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import pytz
import re
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from catboost import CatBoostRegressor
import ipywidgets as widgets

# %% [markdown]
# # Data Wrangling/Exploration
# ## Cleaning
# This data is far from clean and while trying to read the csv file we find that the format of the file contains extra commas that cannot be detected by pandas read_csv function. So this may be an issue with how the data was scraped so we use the on_bad_lines parameter to print which lines are faulty so we can see what is going on.

# %%
df = pd.read_csv('car_prices.csv', header=0, on_bad_lines='warn')
df.head()
# Out:
# b'Skipping line 408163: expected 16 fields, saw 17\nSkipping line 417837: expected 16 fields, saw 17\nSkipping line 421291: expected 16 fields, saw 17\nSkipping line 424163: expected 16 fields, saw 17\n'
# b'Skipping line 427042: expected 16 fields, saw 17\nSkipping line 427045: expected 16 fields, saw 17\nSkipping line 434426: expected 16 fields, saw 17\nSkipping line 444503: expected 16 fields, saw 17\nSkipping line 453796: expected 16 fields, saw 17\n'
# b'Skipping line 461599: expected 16 fields, saw 17\nSkipping line 461614: expected 16 fields, saw 17\n'
# b'Skipping line 492486: expected 16 fields, saw 17\nSkipping line 497010: expected 16 fields, saw 17\nSkipping line 497013: expected 16 fields, saw 17\nSkipping line 499085: expected 16 fields, saw 17\nSkipping line 501457: expected 16 fields, saw 17\nSkipping line 505301: expected 16 fields, saw 17\nSkipping line 505308: expected 16 fields, saw 17\nSkipping line 520463: expected 16 fields, saw 17\n'
# b'Skipping line 528998: expected 16 fields, saw 17\nSkipping line 529011: expected 16 fields, saw 17\nSkipping line 529015: expected 16 fields, saw 17\nSkipping line 529624: expected 16 fields, saw 17\nSkipping line 548786: expected 16 fields, saw 17\nSkipping line 551224: expected 16 fields, saw 17\nSkipping line 554712: expected 16 fields, saw 17\n'
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca        4.5    1331.0   gray    black
# 3  yv1612tb4f1310987    ca        4.1   14282.0  white    black
# 4  wba6b2c57ed129731    ca        4.3    2641.0   gray    black
#
#                                    seller    mmr  sellingprice  \
# 0                 kia motors america, inc  20500         21500
# 1                 kia motors america, inc  20800         21500
# 2  financial services remarketing (lease)  31900         30000
# 3                 volvo na rep/world omni  27500         27750
# 4  financial services remarketing (lease)  66000         67000
#
#                                   saledate
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)

# %% [markdown]
# By copying and pasting the error message and using a little regex, we can extract the lines that were skipped.

# %%
error = "b'Skipping line 408163: expected 16 fields, saw 17\nSkipping line 417837: expected 16 fields, saw 17\nSkipping line 421291: expected 16 fields, saw 17\nSkipping line 424163: expected 16 fields, saw 17\n'\
b'Skipping line 427042: expected 16 fields, saw 17\nSkipping line 427045: expected 16 fields, saw 17\nSkipping line 434426: expected 16 fields, saw 17\nSkipping line 444503: expected 16 fields, saw 17\nSkipping line 453796: expected 16 fields, saw 17\n'\
b'Skipping line 461599: expected 16 fields, saw 17\nSkipping line 461614: expected 16 fields, saw 17\n'\
b'Skipping line 492486: expected 16 fields, saw 17\nSkipping line 497010: expected 16 fields, saw 17\nSkipping line 497013: expected 16 fields, saw 17\nSkipping line 499085: expected 16 fields, saw 17\nSkipping line 501457: expected 16 fields, saw 17\nSkipping line 505301: expected 16 fields, saw 17\nSkipping line 505308: expected 16 fields, saw 17\nSkipping line 520463: expected 16 fields, saw 17\n'\
b'Skipping line 528998: expected 16 fields, saw 17\nSkipping line 529011: expected 16 fields, saw 17\nSkipping line 529015: expected 16 fields, saw 17\nSkipping line 529624: expected 16 fields, saw 17\nSkipping line 548786: expected 16 fields, saw 17\nSkipping line 551224: expected 16 fields, saw 17\nSkipping line 554712: expected 16 fields, saw 17\n'"


regex = r"(\s[0-9]+:)"
skippedLines = re.findall(regex, error)
skippedLines = [int(line[1:-1]) for line in skippedLines]
print(skippedLines)
# Out:
# [408163, 417837, 421291, 424163, 427042, 427045, 434426, 444503, 453796, 461599, 461614, 492486, 497010, 497013, 499085, 501457, 505301, 505308, 520463, 528998, 529011, 529015, 529624, 548786, 551224, 554712]

# %% [markdown]
# Now we will explore if there was a specific pattern for why these lines were skipped and find that there was a formatting error for the trim data. The correct format of the string should have been enclosed in quotes like as follows:
# 'SE PZEV Connectivity,  Navitgation'
#
# So for future pipelines we can change how the data is scraped or read the data in manually line by line and have a specific case for these instances.

# %%
a_file = open('car_prices.csv')
df2 = []
for position, line in enumerate(a_file):
    #have to add 1 cause of the header line
    if position+1 in skippedLines:
        temp = line.replace('w/','').split(',')
        print(temp)
        if temp[4] == ' Navitgation':
            temp[3] = temp[3] + temp[4]
            del temp[4]
        df2.append(temp)  
a_file.close()
# Out:
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'Sedan', 'automatic', '3vwd17aj4fm201708', 'oh', '4.6', '4802', 'silver', 'gray', '"vw credit prequalified"', '13200', '16500', 'Tue Jun 16 2015 02:30:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'Sedan', 'automatic', '3vwd17aj2fm258506', 'ms', '1', '9410', 'white', 'gray', '"enterprise vehicle exchange / tra / birmingham"', '13300', '10500', 'Thu May 07 2015 05:01:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'Sedan', 'automatic', '3vwd17aj3fm276741', 'co', '4.6', '1167', 'blue', 'black', '"tdaf remarketing"', '13200', '12700', 'Tue Jun 16 2015 05:00:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'Sedan', 'automatic', '3vwd17aj2fm285365', 'ms', '1', '2172', 'gray', 'black', '"enterprise vehicle exchange / tra / birmingham"', '14050', '8250', 'Thu May 14 2015 05:01:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'Sedan', 'automatic', '3vwd17aj0fm227318', 'fl', '4.1', '14872', 'gray', 'black', '"enterprise veh exchange/rental"', '13700', '14300', 'Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'Sedan', 'automatic', '3vwd17aj6fm218641', 'fl', '4.9', '12655', 'red', 'black', '"enterprise veh exchange/rental"', '13850', '14500', 'Tue May 26 2015 02:15:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'Sedan', 'automatic', '3vwd17aj7fm223475', 'fl', '4.6', '15719', 'blue', 'black', '"sixt rent a car llc"', '13650', '13500', 'Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'Sedan', 'automatic', '3vwd17aj5fm297123', 'sc', '2', '6388', 'white', 'black', '"enterprise vehicle exchange / tra / rental / tulsa"', '13850', '10700', 'Thu May 21 2015 01:30:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'Sedan', 'automatic', '3vwd17aj5fm219943', 'fl', '4.4', '16633', 'silver', 'black', '"sixt rent a car llc"', '13600', '13600', 'Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'Sedan', 'automatic', '3vwd17aj9fm219766', 'ca', '4.4', '11034', 'black', 'black', '"premium auto wholesale"', '13900', '13000', 'Thu May 28 2015 05:00:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'Sedan', '', '3vwd17aj3fm259017', 'pa', '4.6', '2711', 'white', 'black', '"affordable autos inc"', '14250', '14000', 'Fri May 29 2015 02:15:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', 'automatic', '3vwd17aj5fm206111', 'ca', '2', '6864', 'gray', 'black', '"enterprise vehicle exchange / tra / rental / tulsa"', '14000', '9800', 'Tue Jun 02 2015 05:00:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', 'automatic', '3vwd17aj5fm273601', 'fl', '2.8', '339', 'black', 'black', '"florida auto financial group"', '14300', '12900', 'Tue Jun 02 2015 02:30:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', 'automatic', '3vwd17aj5fm221322', 'fl', '4.8', '18384', 'silver', 'black', '"sixt rent a car llc"', '13550', '13500', 'Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', 'automatic', '3vwd17aj5fm268964', 'in', '2', '9887', 'red', 'black', '"enterprise vehicle exchange / tra / rental / tulsa"', '13900', '9900', 'Wed Jun 03 2015 05:59:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', 'automatic', '3vwd17aj6fm231972', 'va', '3.8', '9837', 'red', 'black', '"enterprise veh exchange/rental"', '13500', '12900', 'Thu Jun 11 2015 02:20:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', '', '3vwd17aj7fm222388', 'ga', '3.6', '20379', 'silver', 'black', '"sixt rent a car llc"', '13600', '13500', 'Thu Jun 04 2015 03:00:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', 'automatic', '3vwd17aj7fm218440', 'ga', '4.2', '20627', 'white', 'black', '"sixt rent a car llc"', '13600', '13500', 'Thu Jun 04 2015 03:00:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', 'automatic', '3vwd17ajxfm315938', 'ca', '1', '721', 'blue', 'gray', '"hertz/tra"', '14100', '8500', 'Tue Jun 09 2015 05:00:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', 'automatic', '3vwd17aj7fm229552', 'va', '3.8', '6158', 'black', 'black', '"enterprise veh exchange/rental"', '13650', '13400', 'Thu Jun 11 2015 02:20:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', '', '3vwd17aj8fm298895', 'pa', '2', '2817', 'red', 'black', '"enterprise-tra"', '13750', '12200', 'Fri Jun 12 2015 01:28:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', 'automatic', '3vwd17aj4fm236636', 'ca', '5', '5705', 'â€”', 'black', '"vw credit prequalified"', '13400', '15250', 'Thu Jun 18 2015 05:30:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', 'automatic', '3vwd17aj5fm225953', 'ga', '4.1', '18561', 'black', 'black', '"sixt rent a car llc"', '13200', '13100', 'Thu Jun 11 2015 03:00:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', 'automatic', '3vwd17aj7fm326640', 'wi', '2', '2846', 'blue', 'black', '"enterprise veh exchange/rental"', '13600', '7500', 'Wed Jun 17 2015 04:30:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', '', '3vwd17aj8fm239622', 'fl', '2', '9562', 'silver', 'black', '"enterprise vehicle exchange / tra / rental / tulsa"', '13200', '12100', 'Mon Jun 15 2015 17:00:00 GMT-0700 (PDT)\n']
# ['2015', 'Volkswagen', 'Jetta', 'SE PZEV Connectivity', ' Navitgation', 'sedan', 'automatic', '3vwd17aj2fm261566', 'tx', '4.8', '5001', 'blue', 'gray', '"mid city mcandrew motors"', '13400', '13600', 'Thu Jun 18 2015 04:00:00 GMT-0700 (PDT)\n']

# %%
df2=pd.DataFrame(data=df2,columns=df.columns)
df.append(df2)
df.reset_index
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca        4.5    1331.0   gray    black
# 3  yv1612tb4f1310987    ca        4.1   14282.0  white    black
# 4  wba6b2c57ed129731    ca        4.3    2641.0   gray    black
#
#                                    seller    mmr  sellingprice  \
# 0                 kia motors america, inc  20500         21500
# 1                 kia motors america, inc  20800         21500
# 2  financial services remarketing (lease)  31900         30000
# 3                 volvo na rep/world omni  27500         27750
# 4  financial services remarketing (lease)  66000         67000
#
#                                   saledate
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)

# %%
(len(df.index) - len(df.dropna().index)) / len(df.index)
# Out:
# 0.15474820645978693

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558811 entries, 0 to 558810
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558811 non-null  int64
#  1   make          548510 non-null  object
#  2   model         548412 non-null  object
#  3   trim          548160 non-null  object
#  4   body          545616 non-null  object
#  5   transmission  493458 non-null  object
#  6   vin           558811 non-null  object
#  7   state         558811 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558717 non-null  float64
#  10  color         558062 non-null  object
#  11  interior      558062 non-null  object
#  12  seller        558811 non-null  object
#  13  mmr           558811 non-null  int64
#  14  sellingprice  558811 non-null  int64
#  15  saledate      558811 non-null  object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 68.2+ MB

# %%
corrMatrix = df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
imp = IterativeImputer(max_iter=10, random_state=0)
np_imp = imp.fit_transform(df[['year', 'condition', 'odometer', 'mmr', 'sellingprice']])
df['condition'] = np_imp[:,1]
df['odometer'] = np_imp[:,2]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558811 entries, 0 to 558810
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558811 non-null  int64
#  1   make          548510 non-null  object
#  2   model         548412 non-null  object
#  3   trim          548160 non-null  object
#  4   body          545616 non-null  object
#  5   transmission  493458 non-null  object
#  6   vin           558811 non-null  object
#  7   state         558811 non-null  object
#  8   condition     558811 non-null  float64
#  9   odometer      558811 non-null  float64
#  10  color         558062 non-null  object
#  11  interior      558062 non-null  object
#  12  seller        558811 non-null  object
#  13  mmr           558811 non-null  int64
#  14  sellingprice  558811 non-null  int64
#  15  saledate      558811 non-null  object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 68.2+ MB

# %%
(len(df.index) - len(df.dropna().index)) / len(df.index)
# Out:
# 0.13788919688409856

# %%
dfnulls = df[df.isna().any(axis=1)]
dfnulls.head()
# Out:
#     year       make             model               trim      body  \
# 16  2015    Hyundai            Sonata                 SE     Sedan
# 35  2014      Buick            Verano  Convenience Group     Sedan
# 44  2014  Chevrolet             Cruze                1LT     Sedan
# 72  2014        BMW               NaN              750Li     Sedan
# 89  2014  Chevrolet  Silverado 2500HD         Work Truck  Crew Cab
#
#    transmission                vin state  condition  odometer  color interior  \
# 16          NaN  5npe24af4fh001562    ca   1.986395    8311.0    red        —
# 35          NaN  1g4pr5sk8e4175320    ca   2.000000   19531.0   gray     gray
# 44          NaN  1g1pc5sb6e7128803    ca   2.017990   38261.0  white        —
# 72    automatic  wbaye8c59ed134514    ca   4.300000   12172.0  black    black
# 89          NaN  1gc1kvc84ef152736    ca   3.600000    8742.0  white     gray
#
#                                                seller    mmr  sellingprice  \
# 16                                           avis tra  15200          4200
# 35  enterprise vehicle exchange / tra / rental / t...  15000          9200
# 44                                           avis tra  11450          2000
# 72             financial services remarketing (lease)  67000         66000
# 89         enterprise fleet management exchange, inc.  34000         34000
#
#                                    saledate
# 16  Tue Dec 16 2014 13:00:00 GMT-0800 (PST)
# 35  Tue Jan 06 2015 04:00:00 GMT-0800 (PST)
# 44  Tue Dec 16 2014 13:00:00 GMT-0800 (PST)
# 72  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
# 89  Thu Dec 18 2014 11:30:00 GMT-0800 (PST)

# %% [markdown]
# ## Feature extracting (Sale Date)
# We can gather more insight by extracting certain aspects of the date such as the year, month, week, etc...

# %%
df['saledate'] = df['saledate'].apply(lambda s: datetime.strptime(s[:-6], '%a %b %d %Y %X %Z%z').astimezone(pytz.utc))

# %%
df['saledate_year'] = df['saledate'].dt.year
df['saledate_month'] = df['saledate'].dt.month
df['saledate_week'] = df['saledate'].dt.isocalendar().week
df['saledate_day'] = df['saledate'].dt.day
df['saledate_hour'] = df['saledate'].dt.hour
df['saledate_minute'] = df['saledate'].dt.minute
df['saledate_dayofweek'] = df['saledate'].dt.dayofweek

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558811 entries, 0 to 558810
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   year                558811 non-null  int64
#  1   make                548510 non-null  object
#  2   model               548412 non-null  object
#  3   trim                548160 non-null  object
#  4   body                545616 non-null  object
#  5   transmission        493458 non-null  object
#  6   vin                 558811 non-null  object
#  7   state               558811 non-null  object
#  8   condition           547017 non-null  float64
#  9   odometer            558717 non-null  float64
#  10  color               558062 non-null  object
#  11  interior            558062 non-null  object
#  12  seller              558811 non-null  object
#  13  mmr                 558811 non-null  int64
#  14  sellingprice        558811 non-null  int64
#  15  saledate            558811 non-null  datetime64[ns, UTC]
#  16  saledate_year       558811 non-null  int64
#  17  saledate_month      558811 non-null  int64
#  18  saledate_week       558811 non-null  UInt32
#  19  saledate_day        558811 non-null  int64
#  20  saledate_hour       558811 non-null  int64
#  21  saledate_minute     558811 non-null  int64
#  22  saledate_dayofweek  558811 non-null  int64
# dtypes: UInt32(1), datetime64[ns, UTC](1), float64(2), int64(9), object(10)
# memory usage: 96.5+ MB

# %%
df.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  472336.000000  472336.000000  472336.000000  472336.000000
# mean     2010.211045       3.426576   66701.070003   13836.999773
# std         3.822131       0.943659   51939.183430    9532.131753
# min      1990.000000       1.000000       1.000000      25.000000
# 25%      2008.000000       2.700000   28137.000000    7425.000000
# 50%      2012.000000       3.600000   51084.000000   12300.000000
# 75%      2013.000000       4.200000   96589.000000   18300.000000
# max      2015.000000       5.000000  999999.000000  182000.000000
#
#         sellingprice  saledate_year  saledate_month  saledate_week  \
# count  472336.000000  472336.000000   472336.000000   472336.00000
# mean    13690.403670    2014.922117        3.621272       13.09156
# std      9612.962279       0.267988        3.042523       11.87743
# min         1.000000    2014.000000        1.000000        1.00000
# 25%      7200.000000    2015.000000        1.000000        5.00000
# 50%     12200.000000    2015.000000        2.000000        8.00000
# 75%     18200.000000    2015.000000        6.000000       22.00000
# max    230000.000000    2015.000000       12.000000       52.00000
#
#         saledate_day  saledate_hour  saledate_minute  saledate_dayofweek
# count  472336.000000  472336.000000    472336.000000       472336.000000
# mean       15.300777      11.424187        17.060959            2.053708
# std         8.628821       3.418792        15.138073            0.984112
# min         1.000000       0.000000         0.000000            0.000000
# 25%         7.000000       9.000000         0.000000            1.000000
# 50%        16.000000      10.000000        20.000000            2.000000
# 75%        22.000000      12.000000        30.000000            3.000000
# max        31.000000      23.000000        59.000000            6.000000

# %%
num = ['year', 'condition','odometer','mmr','sellingprice','saledate_year','saledate_month','saledate_week','saledate_day','saledate_hour','saledate_minute','saledate_dayofweek']
print(f'=== Distribution of features (before log transformation) ===')
plt.figure(figsize=(30, 30))
for i, col in enumerate(num):
    # Plot distribution 
    plt.subplot(4,3,i+1); sns.histplot(df[col], color='blue')
    plt.title(f'Distribution of {col}')
# Show the plot
plt.tight_layout()
plt.show()
# Out:
# === Distribution of features (before log transformation) ===

# %%
# Log transform function
def log_transform(data, to_log):
    X = data.copy()
    for item in to_log:
        # Add 1 to the data to prevent infinity values
        X[item] = np.log(1+X[item])
    return X

# %%
to_log = ['condition','odometer','mmr','sellingprice']
df_log = log_transform(df, to_log)
df_log.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  ...        mmr sellingprice  \
# 0  5xyktca69fg566472    ca   1.791759  9.719565  ...   9.928229     9.975855
# 1  5xyktca69fg561319    ca   1.791759  9.147826  ...   9.942756     9.975855
# 2  wba3c1c51ek116351    ca   1.704748  7.194437  ...  10.370393    10.308986
# 3  yv1612tb4f1310987    ca   1.629241  9.566825  ...  10.221978    10.231027
# 4  wba6b2c57ed129731    ca   1.667707  7.879291  ...  11.097425    11.112463
#
#                    saledate  saledate_year  saledate_month saledate_week  \
# 0 2014-12-16 20:30:00+00:00           2014              12            51
# 1 2014-12-16 20:30:00+00:00           2014              12            51
# 2 2015-01-15 12:30:00+00:00           2015               1             3
# 3 2015-01-29 12:30:00+00:00           2015               1             5
# 4 2014-12-18 20:30:00+00:00           2014              12            51
#
#    saledate_day  saledate_hour  saledate_minute  saledate_dayofweek
# 0            16             20               30                   1
# 1            16             20               30                   1
# 2            15             12               30                   3
# 3            29             12               30                   3
# 4            18             20               30                   3
#
# [5 rows x 23 columns]

# %%
# Check distribution (num)
print(f'=== Distribution of features (after log transformation) ===')
plt.figure(figsize=(30, 30))
for i, col in enumerate(num):
    # Plot distribution 
    plt.subplot(4,3,i+1); sns.histplot(df_log[col], color='blue')
    plt.title(f'Distribution of {col}')
# Show the plot
plt.tight_layout()
plt.show()
# Out:
# === Distribution of features (after log transformation) ===

# %%
# Check distribution (cat)
print(f'=== Distribution of categorical features  ===')
non_num = ['make', 'model', 'body', 'transmission', 'state', 'color', 'interior']
plt.figure(figsize=(30, 30))
for i, col in enumerate(non_num):
    # Plot distribution 
    plt.subplot(4,3,i+1); sns.histplot(df_log[col], color='blue')
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=90)
# Show the plot
plt.tight_layout()
plt.show()
# Out:
# === Distribution of categorical features  ===

# %%
df_log.columns
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate', 'saledate_year', 'saledate_month',
#        'saledate_week', 'saledate_day', 'saledate_hour', 'saledate_minute',
#        'saledate_dayofweek'],
#       dtype='object')

# %%
df_log.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 472336 entries, 0 to 558810
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   year                472336 non-null  int64
#  1   make                472336 non-null  object
#  2   model               472336 non-null  object
#  3   trim                472336 non-null  object
#  4   body                472336 non-null  object
#  5   transmission        472336 non-null  object
#  6   vin                 472336 non-null  object
#  7   state               472336 non-null  object
#  8   condition           472336 non-null  float64
#  9   odometer            472336 non-null  float64
#  10  color               472336 non-null  object
#  11  interior            472336 non-null  object
#  12  seller              472336 non-null  object
#  13  mmr                 472336 non-null  float64
#  14  sellingprice        472336 non-null  float64
#  15  saledate            472336 non-null  datetime64[ns, UTC]
#  16  saledate_year       472336 non-null  int64
#  17  saledate_month      472336 non-null  int64
#  18  saledate_week       472336 non-null  UInt32
#  19  saledate_day        472336 non-null  int64
#  20  saledate_hour       472336 non-null  int64
#  21  saledate_minute     472336 non-null  int64
#  22  saledate_dayofweek  472336 non-null  int64
# dtypes: UInt32(1), datetime64[ns, UTC](1), float64(4), int64(7), object(10)
# memory usage: 85.1+ MB

# %%
# df_log['odometer_binned'] = pd.qcut(df_log['odometer'], q=20)
# df_log['mmr_binned'] = pd.qcut(df_log['mmr'], q=20)
finalDf = df_log.drop(['vin','saledate'], axis=1)
finalDf["year"]=df_log["year"].astype(str)
finalDf["saledate_year"]=df_log["saledate_year"].astype(str)
finalDf["saledate_month"]=df_log["saledate_month"].astype(str)
finalDf["saledate_week"]=df_log["saledate_week"].astype(str)
finalDf["saledate_day"]=df_log["saledate_day"].astype(str)
finalDf["saledate_hour"]=df_log["saledate_hour"].astype(str)
finalDf["saledate_minute"]=df_log["saledate_minute"].astype(str)
finalDf["saledate_dayofweek"]=df_log["saledate_dayofweek"].astype(str)
finalDf.nunique()
# Out:
# year                      26
# make                      53
# model                    768
# trim                    1507
# body                      85
# transmission               2
# state                     34
# condition                 41
# odometer              160427
# color                     20
# interior                  17
# seller                 11927
# mmr                     1099
# sellingprice            1806
# saledate_year              2
# saledate_month             8
# saledate_week             32
# saledate_day              31
# saledate_hour             21
# saledate_minute           40
# saledate_dayofweek         7
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = finalDf.drop("sellingprice", axis=1)
y = finalDf[["sellingprice"]]

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
categorical_features_indices = np.where(X.dtypes != np.float)[0]
print(categorical_features_indices)
# Out:
# [ 0  1  2  3  4  5  6  9 10 11 13 14 15 16 17 18 19]

# %%
model=CatBoostRegressor(iterations=100, depth=10, learning_rate=0.1, loss_function='RMSE')
model.fit(X_train, y_train,cat_features=categorical_features_indices,eval_set=(X_val, y_val),plot=True);
# Out:
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.8101757	test: 0.8048728	best: 0.8048728 (0)	total: 150ms	remaining: 14.9s
# 1:	learn: 0.7379388	test: 0.7330032	best: 0.7330032 (1)	total: 276ms	remaining: 13.5s
# 2:	learn: 0.6729321	test: 0.6684188	best: 0.6684188 (2)	total: 419ms	remaining: 13.6s
# 3:	learn: 0.6153368	test: 0.6111928	best: 0.6111928 (3)	total: 570ms	remaining: 13.7s
# 4:	learn: 0.5633665	test: 0.5595523	best: 0.5595523 (4)	total: 690ms	remaining: 13.1s
# 5:	learn: 0.5169194	test: 0.5133706	best: 0.5133706 (5)	total: 809ms	remaining: 12.7s
# 6:	learn: 0.4768663	test: 0.4734760	best: 0.4734760 (6)	total: 965ms	remaining: 12.8s
# 7:	learn: 0.4401546	test: 0.4369978	best: 0.4369978 (7)	total: 1.1s	remaining: 12.7s
# 8:	learn: 0.4078831	test: 0.4049235	best: 0.4049235 (8)	total: 1.23s	remaining: 12.4s
# 9:	learn: 0.3797332	test: 0.3769475	best: 0.3769475 (9)	total: 1.35s	remaining: 12.2s
# 10:	learn: 0.3547213	test: 0.3520832	best: 0.3520832 (10)	total: 1.48s	remaining: 11.9s
# 11:	learn: 0.3330460	test: 0.3304868	best: 0.3304868 (11)	total: 1.59s	remaining: 11.7s
# 12:	learn: 0.3143861	test: 0.3119474	best: 0.3119474 (12)	total: 1.71s	remaining: 11.5s
# 13:	learn: 0.2979480	test: 0.2955851	best: 0.2955851 (13)	total: 1.83s	remaining: 11.3s
# 14:	learn: 0.2836995	test: 0.2814290	best: 0.2814290 (14)	total: 1.95s	remaining: 11.1s
# 97:	learn: 0.1855436	test: 0.1877019	best: 0.1877019 (97)	total: 12.2s	remaining: 249ms
# 98:	learn: 0.1854109	test: 0.1876572	best: 0.1876572 (98)	total: 12.3s	remaining: 124ms
# 99:	learn: 0.1853435	test: 0.1876024	best: 0.1876024 (99)	total: 12.4s	remaining: 0us
#
# bestTest = 0.1876023642
# bestIteration = 99

# %%
def plot_feature_importance(importance,names,model_type):
    
    #Create arrays from feature importance and feature names
    feature_importance = np.array(importance)
    feature_names = np.array(names)
    
    #Create a DataFrame using a Dictionary
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)
    
    #Sort the DataFrame in order decreasing feature importance
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    
    #Define size of bar plot
    plt.figure(figsize=(10,8))
    #Plot Searborn bar chart
    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])
    #Add chart labels
    plt.title(model_type + 'FEATURE IMPORTANCE')
    plt.xlabel('FEATURE IMPORTANCE')
    plt.ylabel('FEATURE NAMES')

# %%
plot_feature_importance(model.get_feature_importance(),X_train.columns,'CATBOOST')

# %%
X_train2 = X_train.drop('mmr', axis=1)
categorical_features_indices2 = np.where(X_train2.dtypes != np.float)[0]
X_val2 = X_val.drop('mmr', axis=1)
print(categorical_features_indices)
model2=CatBoostRegressor(iterations=100, depth=10, learning_rate=0.1, loss_function='RMSE')
model2.fit(X_train2, y_train,cat_features=categorical_features_indices2,eval_set=(X_val2, y_val),plot=True);
# Out:
# [ 0  1  2  3  4  5  6  9 10 11 13 14 15 16 17 18 19]
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.8218188	test: 0.8164758	best: 0.8164758 (0)	total: 158ms	remaining: 15.6s
# 1:	learn: 0.7608292	test: 0.7557673	best: 0.7557673 (1)	total: 273ms	remaining: 13.4s
# 2:	learn: 0.7049893	test: 0.7003559	best: 0.7003559 (2)	total: 397ms	remaining: 12.8s
# 3:	learn: 0.6552611	test: 0.6507025	best: 0.6507025 (3)	total: 533ms	remaining: 12.8s
# 4:	learn: 0.6114320	test: 0.6067130	best: 0.6067130 (4)	total: 657ms	remaining: 12.5s
# 5:	learn: 0.5730918	test: 0.5681635	best: 0.5681635 (5)	total: 775ms	remaining: 12.1s
# 6:	learn: 0.5393318	test: 0.5344564	best: 0.5344564 (6)	total: 904ms	remaining: 12s
# 7:	learn: 0.5107068	test: 0.5058795	best: 0.5058795 (7)	total: 1.09s	remaining: 12.5s
# 8:	learn: 0.4845469	test: 0.4798229	best: 0.4798229 (8)	total: 1.21s	remaining: 12.3s
# 9:	learn: 0.4619609	test: 0.4573480	best: 0.4573480 (9)	total: 1.34s	remaining: 12s
# 10:	learn: 0.4419092	test: 0.4376113	best: 0.4376113 (10)	total: 1.46s	remaining: 11.8s
# 11:	learn: 0.4246128	test: 0.4204962	best: 0.4204962 (11)	total: 1.58s	remaining: 11.6s
# 12:	learn: 0.4098112	test: 0.4058293	best: 0.4058293 (12)	total: 1.7s	remaining: 11.4s
# 13:	learn: 0.3955856	test: 0.3919471	best: 0.3919471 (13)	total: 1.82s	remaining: 11.2s
# 14:	learn: 0.3835552	test: 0.3797373	best: 0.3797373 (14)	total: 1.94s	remaining: 11s
# 15:	learn: 0.3726846	test: 0.3690255	best: 0.3690255 (15)	total: 2.06s	remaining: 10.8s
# 16:	learn: 0.3637648	test: 0.3601449	best: 0.3601449 (16)	total: 2.18s	remaining: 10.6s
# 17:	learn: 0.3557307	test: 0.3521489	best: 0.3521489 (17)	total: 2.29s	remaining: 10.5s
# 18:	learn: 0.3481044	test: 0.3445516	best: 0.3445516 (18)	total: 2.41s	remaining: 10.3s
